# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# ## Enhance the combined file with faculty information
# - Note that this notebook does not have to run every time as this is used to update a file called "acad_prog.csv" in data folder
# ("data/acad_prog.csv")
#
# - We use the following code to identify acad_prog that has fewer people. We then merge these small user groups (e.g. merge the part-time data with the full-time data) to protect the identity for the users

# %%
import pandas as pd

# %%
dff=pd.read_excel("data/acadprog.xlsx",index_col="acad_prog")
dff.head()

dff['acad_prog_c']=dff.index.values
dff.sort_values(by="Grandtotal")[:20]


#df[dff.filter(like="Science")]
# Out:
#                                   1    2   3    4    G  Grandtotal FT/PT  \
# acad_prog
# Science Special                 1.0  NaN NaN  NaN  NaN           1    FT
# Justice Studies Part-time       1.0  NaN NaN  NaN  NaN           1    PT
# Electrical Engineering          NaN  NaN NaN  1.0  NaN           1    FT
# PhD Communication & Culture PT  NaN  NaN NaN  NaN  1.0           1    PT
# BT Enterprise Sys. & Org. CTPT  1.0  NaN NaN  NaN  NaN           1    PT
# Biology                         NaN  NaN NaN  1.0  NaN           1    FT
# Administration and Information  1.0  NaN NaN  NaN  NaN           1    FT
# MASc Elec & Computer Eng PT     NaN  NaN NaN  NaN  1.0           1    PT
# Politics and Governance         NaN  NaN NaN  1.0  NaN           1    FT
# MA Child and Youth Care P/T     NaN  NaN NaN  NaN  2.0           2    PT
# PhD Math Modelling & Methods    NaN  NaN NaN  NaN  2.0           2    FT
# MEng Chemical Engineering PT    NaN  NaN NaN  NaN  2.0           2    PT
# ...

# %% [markdown]
# - The following code is also helpful, as it helps to identify th name of acad_prog that would require a merge. In the example below, we use 'filter' to identify acad_prog that has the word "Special" in it

# %%
dfffilter=dff.filter(like="Special",axis=0)
print(dfffilter)
# Out:
#                                   1   2   3   4    G  Grandtotal FT/PT  \
# acad_prog
# Engineering Special            89.0 NaN NaN NaN  NaN          89    FT
# Special Student Status         89.0 NaN NaN NaN  NaN          89    FT
# Business Special               68.0 NaN NaN NaN  NaN          68    FT
# Architectural Science Special   3.0 NaN NaN NaN  NaN           3    FT
# Special Grad Status             NaN NaN NaN NaN  9.0           9    FT
# Science Special                 1.0 NaN NaN NaN  NaN           1    FT
#
#                                                  acad_prog_c  Undergrad  \
# acad_prog
# Engineering Special                      Engineering Special  Undergrad
# Special Student Status                Special Student Status  Undergrad
# Business Special                            Business Special  Undergrad
# Architectural Science Special  Architectural Science Special  Undergrad
# Special Grad Status                      Special Grad Status       Grad
# ...

# %% [markdown]
# - After the cleanup, we create a file "acadprog.xlsx" that could be used for further processing

# %%
dff.acad_prog_c=dff.acad_prog_c.replace("Science Special","Bachelor of Science")
dff.acad_prog_c=dff.acad_prog_c.replace("Biology","Bachelor of Science")
dff.acad_prog_c=dff.acad_prog_c.replace("Architectural Science Special","Architectural Science")
dff.acad_prog_c=dff.acad_prog_c.replace("Electrical Engineering","Bachelor of Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("Politics and Governance","Public Admin and Governance")
dff.acad_prog_c=dff.acad_prog_c.replace("Justice Studies Part-time","Public Admin and Governanc")
dff.acad_prog_c=dff.acad_prog_c.replace("Administration and Information","Public Admin and Governanc")
dff.acad_prog_c=dff.acad_prog_c.replace("MASc Elec & Computer Eng PT","MASc Electrical & Computer Eng")
#dff.acad_prog_c=dff.acad_prog_c.replace("P/T","")
#dff.acad_prog_c=dff.acad_prog_c.replace("PT","")
dff.acad_prog_c=dff.acad_prog_c.replace("PhD Communication & Culture PT","PhD Communication & Culture")
dff.acad_prog_c=dff.acad_prog_c.replace("Aerospace Design Mgmt PMDip","MASC Aerospace Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("Public Admin and Governanc","Public Admin and Governance")
dff.acad_prog_c=dff.acad_prog_c.replace("MA Child and Youth Care P/T","MA Child and Youth Care")
dff.acad_prog_c=dff.acad_prog_c.replace("MEng Biomedical Engineering PT","Postgrad Biomedical Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("MEng Chemical Engineering PT","MEng Chemical Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("MSc Applied Mathematics","MSc PhD Math")
dff.acad_prog_c=dff.acad_prog_c.replace("PhD Math Modelling & Methods","MSc PhD Math")
dff.acad_prog_c=dff.acad_prog_c.replace("MA Immigration & Settlement PT","MA Immigration & Settlement")
dff.acad_prog_c=dff.acad_prog_c.replace("Post Baccalaureate Midwifery ","MA Immigration & Settlement")
dff.acad_prog_c=dff.acad_prog_c.replace("MA Communication & Culture PT","MA Communication & Culture")
dff.acad_prog_c=dff.acad_prog_c.replace("Primary Hlth Care Nurs Prac","Postgrad Nursing and Midwifery")
dff.acad_prog_c=dff.acad_prog_c.replace("Spatial Analysis PT","Geog or Spatial Analysis")
dff.acad_prog_c=dff.acad_prog_c.replace("Geographic Analysis","Geog or Spatial Analysis")
dff.acad_prog_c=dff.acad_prog_c.replace("BT Enterprise Sys. & Org. CTPT","Business Management")
dff.acad_prog_c=dff.acad_prog_c.replace("Engr Innov & Entreprnshp P/T","Engr Innovation & Entreprnshp")
dff.acad_prog_c=dff.acad_prog_c.replace("MASc Biomedical Engineering","Postgrad Biomedical Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("MEng Biomedical Engineering","Postgrad Biomedical Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("PhD Biomedical Engineering","Postgrad Biomedical Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("Energy and Innovation PMDip","Engr Innovation & Entreprnshp")
dff.acad_prog_c=dff.acad_prog_c.replace("Post Baccalaureate Midwifery","Postgrad Nursing and Midwifery")
dff.acad_prog_c=dff.acad_prog_c.replace("MN Nursing Full-Time","Postgrad Nursing and Midwifery")
dff.acad_prog_c=dff.acad_prog_c.replace("MN Nursing Part-Time","Postgrad Nursing and Midwifery")
dff.acad_prog_c=dff.acad_prog_c.replace("MSc Data Sci and Analytics P/T","MSc Data Science and Analytics")
dff.acad_prog_c=dff.acad_prog_c.replace("Envir.App.Sci. & Mgt. PT","Envir. App.Sci.& Mgt.")
dff.acad_prog_c=dff.acad_prog_c.replace("Urban & Regional Plan DC","Urban & Regional Planning")
dff.acad_prog_c=dff.acad_prog_c.replace("Urban & Regional Plan PB","Urban & Regional Planning")
dff.acad_prog_c=dff.acad_prog_c.replace("MASc Computer Networks","Postgrad Computer Networks")
dff.acad_prog_c=dff.acad_prog_c.replace("MEng Computer Networks","Postgrad Computer Networks")
dff.acad_prog_c=dff.acad_prog_c.replace("MEng Computer Networks PT","Postgrad Computer Networks")
dff.acad_prog_c=dff.acad_prog_c.replace("PhD Chemical Engineering","Postgrad Chemical Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("MEng Chemical Engineering","Postgrad Chemical Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("MEng Aerospace Eng PT","MENG Aerospace Engineering")
dff.acad_prog_c=dff.acad_prog_c.replace("Special Grad Status","Special Student Status")
dff.acad_prog_c=dff.acad_prog_c.replace("MSc Data Sci and Analytics P/T","MSc Data Science and Analytics")
dff.acad_prog_c=dff.acad_prog_c.replace("MSc Data Sci and Analytics P/T","MSc Data Science and Analytics")
dff.acad_prog_c=dff.acad_prog_c.replace("MSc Data Sci and Analytics P/T","MSc Data Science and Analytics")



#dff.acad_prog_c=dff.acad_prog_c.str.replace('P/T',"")

#dff.acad_prog_c=dff.acad_prog_c.str.replace('PT',"")
#dff.acad_prog_c=dff.acad_prog_c.str.strip('')

dff['acad_prog_c']=dff['acad_prog_c'].fillna("staff")

dff.to_csv("data/acad_prog.csv")
dff.to_excel("data/acadprog.xlsx")
#dff2=dff.drop([''])

#dfg=df.groupby(["domain","acad_prog",'prog_yr'])['prog_yr'].count().fillna(0)


dff1=dff.groupby(['acad_prog_c'])['Grandtotal'].sum().sort_values()[:20]
dff1.head(20)
# Out:
# acad_prog_c
# Entrprs Info Protection PMDip    11
# Int'l Economics & Fin. PT        11
# Dietetics PMDip FT               12
# MASc Building Science            12
# MBSc Building Science PT         13
# Geog or Spatial Analysis         13
# BusinessTech Mgt CAAT PT         16
# Postgrad Chemical Engineering    18
# PhD  Economics                   19
# PhD Molecular Science            19
# MEng Mechanical Eng PT           19
# MEng Civil Engineering PT        20
# MA Child and Youth Care          20
# MA Early Childhood Studies PT    20
# MBA Mgmt of Technol and Innov    21
# Phd Biomedical Physics           21
# MA Literatures of Modernity      22
# MBSc Building Science            22
# MA Early Childhood Studies       22
# MA Public Policy & Admin. PT     23
# Name: Grandtotal, dtype: int64

# %%
dff.sort_values(by="Grandtotal")[:25]
# Out:
#                                   1    2   3    4    G  Grandtotal FT/PT  \
# acad_prog
# Science Special                 1.0  NaN NaN  NaN  NaN           1    FT
# Justice Studies Part-time       1.0  NaN NaN  NaN  NaN           1    PT
# Electrical Engineering          NaN  NaN NaN  1.0  NaN           1    FT
# PhD Communication & Culture PT  NaN  NaN NaN  NaN  1.0           1    PT
# BT Enterprise Sys. & Org. CTPT  1.0  NaN NaN  NaN  NaN           1    PT
# Biology                         NaN  NaN NaN  1.0  NaN           1    FT
# Administration and Information  1.0  NaN NaN  NaN  NaN           1    FT
# MASc Elec & Computer Eng PT     NaN  NaN NaN  NaN  1.0           1    PT
# Politics and Governance         NaN  NaN NaN  1.0  NaN           1    FT
# MA Child and Youth Care P/T     NaN  NaN NaN  NaN  2.0           2    PT
# PhD Math Modelling & Methods    NaN  NaN NaN  NaN  2.0           2    FT
# MEng Chemical Engineering PT    NaN  NaN NaN  NaN  2.0           2    PT
# ...

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
